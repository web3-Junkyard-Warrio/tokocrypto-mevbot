# %%
import os, glob
import pandas as pd

# %%
path = "/Users/caesar/Downloads"

# %%
all_files = glob.glob(os.path.join(path, "*.csv"))

# %%
all_csv = (pd.read_csv(f, sep=',') for f in all_files)

# %%
df_merged = pd.concat(all_csv, ignore_index=True)

# %%
df_merged.to_csv("Author_Pintu.csv", index=False)

# %%
df_merged.head()
# Out:
#   accountType                         added  assignment   author  \
# 0  individual  2022-03-14T13:26:39.132+0000         NaN  PintuID
# 1  individual  2022-03-14T13:26:39.132+0000         NaN  PintuID
# 2  individual  2022-03-13T11:22:32.383+0000         NaN  PintuID
# 3  individual  2022-03-11T11:37:48.838+0000         NaN  PintuID
# 4  individual  2022-03-11T11:38:22.552+0000         NaN  PintuID
#
#                                            avatarUrl  blogName categories  \
# 0  https://audiences.brandwatch.com/api/audiences...       NaN         []
# 1  https://audiences.brandwatch.com/api/audiences...       NaN         []
# 2  https://audiences.brandwatch.com/api/audiences...       NaN         []
# 3  https://audiences.brandwatch.com/api/audiences...       NaN         []
# 4  https://audiences.brandwatch.com/api/audiences...       NaN         []
#
#   categoryDetails  checked  city  ...                       updated  \
# ...
